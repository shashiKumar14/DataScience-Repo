# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/avnyadav/sensor-fault-detection/main/aps_failure_training_set1.csv")
df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000  ag_001  \
# 0       pos  153204      0         182     na      0      0      0       0
# 1       pos  453236     na        2926     na      0      0      0       0
# 2       pos   72504     na        1594   1052      0      0      0     244
# 3       pos  762958     na          na     na     na     na    776  281128
# 4       pos  695994     na          na     na     na     na      0       0
# ...     ...     ...    ...         ...    ...    ...    ...    ...     ...
# 36183   neg  153002     na         664    186      0      0      0       0
# 36184   neg    2286     na  2130706538    224      0      0      0       0
# 36185   neg     112      0  2130706432     18      0      0      0       0
# 36186   neg   80292     na  2130706432    494      0      0      0       0
# 36187   neg   40222     na         698    628      0      0      0       0
#
# ...

# %%
df.reset_index(inplace = True, drop = True)
  
df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000  ag_001  \
# 0       pos  153204      0         182     na      0      0      0       0
# 1       pos  453236     na        2926     na      0      0      0       0
# 2       pos   72504     na        1594   1052      0      0      0     244
# 3       pos  762958     na          na     na     na     na    776  281128
# 4       pos  695994     na          na     na     na     na      0       0
# ...     ...     ...    ...         ...    ...    ...    ...    ...     ...
# 36183   neg  153002     na         664    186      0      0      0       0
# 36184   neg    2286     na  2130706538    224      0      0      0       0
# 36185   neg     112      0  2130706432     18      0      0      0       0
# 36186   neg   80292     na  2130706432    494      0      0      0       0
# 36187   neg   40222     na         698    628      0      0      0       0
#
# ...

# %%
import requests
with open("D:\\ineuronvsfiles\\DataScience-Repo\\Notebooks\\ML\\Aps.ipynb","wb") as f:
    f.write(requests.get("https://raw.githubusercontent.com/yadav-avnish/aps-fault-detection/main/notebook/Scania_APS_failure_prediction.ipynb").content)

# %%
pwd
# Out:
# 'D:\\ineuronvsfiles\\DataScience-Repo\\Notebooks\\ML'
